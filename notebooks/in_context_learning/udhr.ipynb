# %% [markdown]
# # Title

# %%
from openai import OpenAI
import nltk
from nltk.tokenize.treebank import TreebankWordDetokenizer
import random
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
client = OpenAI()
detokenize = TreebankWordDetokenizer().detokenize

# %%
corpus = pd.concat([pd.Series([s for s in nltk.corpus.udhr.sents(f) if len(s) > 10], name = f[:-7]) for f in nltk.corpus.udhr.fileids() if 'Latin1' in f], axis = 1)
min_num_sentences = min([len([s for s in nltk.corpus.udhr.sents(f) if len(s) > 10]) for f in nltk.corpus.udhr.fileids() if 'Latin1' in f])
corpus = corpus.head(min_num_sentences)

# %%
corpus
# Out:
#                                             Achehnese  \
# 0   [PEUNYATAANUMUM, TEUNTANG, HAK, -, HAK, ASASI,...
# 1   [Tiep, ureung, lahee, dengon, hak, -, hak, dro...
# 2   [Pane, ", komitmen, ", bak, awai, phon, ,, put...
# 3   [Cempala, kuneng, jipoue, ue, baroh, cicem, ce...
# 4   [PEUNYATAAN, UMUM, TEUNTANG, HAK, ASASI, MANUS...
# 5   [P, a, s, a, i, 1, Bandum, manusia, lahee, beb...
# 6   [Ngon, akai, taseumikee, ,, ngon, atee, tameur...
# 7   [P, a, s, a, i, 2, Tiep, ureung, na, hak, saba...
# 8   [Basa, ,, agama, ,, sukee, ngon, bangsa, hana,...
# 9   [P, a, s, a, i, 3, Ureung, droe, -, droe, bak,...
# 10  [P, a, s, a, i, 4, Hana, sidroe, ureung, bak, ...
# 11  [P, a, s, a, i, 5, Tan, sidroe, ureung, patot,...
# 12  [P, a, s, a, i, 6, Tiep, -, tiep, ureung, cit,...
# 13  [P, a, s, a, i, 7, Tiep, ureung, saban, bak, m...
# 14  [Patot, hai, rakan, tanyoe, tapuphom, hanjeut,...
# 15  [P, a, s, a, i, 8, Tiep, ureung, na, hak, teur...
# 16  [P, a, s, a, i, 9, Hana, sidroe, ureung, hai, ...
# 17  [P, a, s, a, i, 10, Bandum, ureung, ,, hai, te...
# 18  [Barangasoe, didakwa, lee, hukom, hanjeut, hai...
#
#                                        Achuar-Shiwiar  \
# 0   [Mash, Nungkanam, Pujuinau, Angkan, Pengker, P...
# 1   [Antsu, mash, metek, nuwanmaya, akiinau, asar,...
# 2   [Tura, waininayat, nuna, nintimtsuk, aints, ai...
# 3   [Tura, asaramtai, mash, nungkanmaya, ainau, nu...
# 4   [Apu, ainau, wina, yaintsuk, pachichamtaisha, ...
# 5   [Tu, tinau, asamtai, apu, ainau, :, Atsa, ,, m...
# 6   [Tura, asar, chikich, nungkanmaya, ainaujai, m...
# 7   [Apu, ainau, iruntramunam, aints, tu, pujusart...
# 8   [Tura, asar, aints, ainau, iruntrar, maanitsuk...
# 9   [Tura, chikich, nungkanmaya, ainauka, iruntrar...
# 10  [Apu, ainau, mash, nungkanam, pujuinau, ni, ai...
# 11  [Aints, mash, metek, nuwanmaya, akiinau, asar,...
# 12  [Tura, asaramtai, aints, ainau, nuna, nekaawar...
# 13  [Tura, asar, :, Apu, Ainau, Iruntrar, Pujuinam...
# 14  [Ju, aarmauka, pengke, kajinmatsuk, juun, aina...
# 6   [Jaa, nutuztirazin, jaha, jonivaun, jaton, hap...
# 7   [Cooncovin, jaton, nutunxon, jahoxanhquin, nut...
# 8   [Articulo, 2, Nan, quiricanan, jau, cuzati, qu...
# 9   [Joxohocatzi, chaho, ,, vinshinhocatzi, panshi...
# 10  [Rato, partido, politico, tanahirahcanihqui, ,...
# 11  [Vutza, nutun, jato, jaton, nutu, hinaahancun,...
# 12  [Articulo, 4, Jamun, haruzquin, jonitzan, tzov...
# 13  [Articulo, 6, Quiyoo, nutunxon, jato, jaton, n...
# 14  [Nan, quiricanan, cunuunivo, ja, jahayamaquin,...
# 15  [Articulo, 8, Ja, nutun, jaha, juesvaun, jato,...
# 16  [Jaton, jato, hiromativo, shinanquin, ja, jaha...
# 17  [Articulo, 9, Pishtacovin, tzova, jau, cuzayam...
# 18  [Cooncovin, hiromaquin, jau, cuzahazquinhcain,...
#
#                                            Amarakaeri  \
# 0   [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 1   [Kena, ', po, oro, ', huadakda, ka, ', dik, o,...
# 2   [Kena, ', po, aya, ', da, oro, ', taj, dakhuap...
# 3   [Kenpa, ', ti, oro, ', taj, nama, ', da, e, ',...
# 4   [Daka, ', da, e, ', nigpeetada, dakhuea, ', ek...
# 5   [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 6   [Huabokerek, kenda, oknopoehue, ', o, ', nepo,...
# 7   [Kena, ', po, ,, Do, ', huedbayo, kenda, ijnop...
# 8   [Dakhuea, ', huaka, ', eri, huakka, ', aratbut...
# 9   [Dakhuea, ', huaka, ', eritaj, aratbutnayo, ba...
# 10  [Gobierno, huairi, e, ', mana, ', nigmadoya, '...
# 11  [Kenda, aratbut, nogda, nogda, huadakda, ka, '...
# 12  [Huadaribayo, huairi, nog, huadaribayo, huairi...
# 13  [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 14  [Oro, ', nogbayo, nogbayo, gobierno, huairi, o...
# 15  [Aya, ', da, huabokerek, konigti, huadakda, o,...
# 16  [Huabokerekere, ettone, ', ere, konigti, huada...
# 17  [Nogiti, nogiti, nogomeya, e, ', tihuapok, ken...
# 18  [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
#
#                                               Arabela  \
# 0   [PUETUNU, PUEYAPUEECUARAJANAA, NIYA, NAAJIOSAA...
# 1   [Pocua, naa, quiri, paa, jaara, rerequeteyaqui...
# 2   [Paa, niishiyani, :, pueya, jaara, jiyaniquiaa...
# 3   [Maninia, pueyari, shiriiquirii, na, niishisha...
# 4   [Pueya, jaara, sesa, niishiyajaa, naa, ,, maja...
# 5   [Paa, cartesano, quiniu, paniyapa, sequenura, ...
# 6   [Paa, niishiyani, :, pueya, cuaara, maninia, j...
# 7   [Paa, niishiyani, :, pueya, cuaara, jiyano, ¿,...
# 8   [Paa, niishiyani, :, puetunu, pajaniyajanaa, p...
# 9   [Paa, mariyata, sequequiaari, :, -, Pa, poonij...
# 10  [Paa, niishiyani, :, puetunu, jiyaniijiajanaar...
# 11  [Paa, niishiyani, :, Noojiaqueya, pueya, niish...
# 12  [Naaratej, :, Puetunu, canaaj, anaa, canaa, re...
# 13  [Nia, numaama, nia, racatare, canaa, sequesano...
# 14  [Jiyaniijianucua, cuaara, sequeera, taa, miish...
# 15  [Cuaara, niishitiojosaaria, puetunu, na, pueya...
# 16  [Pueyano, pa, quishacari, ,, puetunu, pajaniya...
# 17  [Na, camaru, mariyata, maninia, miishiya, taa,...
# 18  [Mariyata, sesa, miijia, maja, saniitioshiya, ...
#
#                                             Ashaninca  ...  \
# 0   [Ocarataque, 10, de, diciembre, ,, 1948, ,, ya...  ...
# 1   [Aisati, icanti, ocameetsati, asanquenateneri,...  ...
# 2   [Ocameetsati, avaraaquero, jaocarica, isavicaj...  ...
# 3   [Te, oncameetsateji, imperanajeitee, itsipapee...  ...
# 4   [Aisati, ariorica, acoaque, anquemisanteri, Ta...  ...
# 5   [Te, ancoyeji, intime, quisheene, ;, irointi, ...  ...
# 6   [Tempa, aisati, ocameetsati, irijocacoventajei...  ...
# 7   [Aisati, ariorica, iroashinoncaajeitee, itsipa...  ...
# 8   [Icameetsajeitaque, maaroni, atiri, :, te, onc...  ...
# 9   [Timatsi, ametapinijeitán, aisati, acoajeitiri...  ...
# 10  [Acarajeitiri, Naciones, Unidas, ,, maaroni, :...  ...
# 11  [Irootaque, isanquenajeitantarori, yora, ASAMB...  ...
# 12  [Aquempetavacaajeita, maaroni, atiri, ., Timat...  ...
# 13  [Te, oncameetsateji, imperanajeitee, ,, te, on...  ...
# 14  [Tempa, amoncaratavacaaj, ej, taca, ,, eiro, a...  ...
# 15  [Pinashita, ,, te, pishanincatenaji, ,, onashi...  ...
# 16  [Te, oncameetsateji, ancantayetero, ocapee, ,,...  ...
# 17  [Te, oncameetsateji, iroyeetee, ,, te, oncamee...  ...
# 18  [Te, oncameetsateji, iroatsinayeeteri, atiri, ...  ...
#
#                          WesternSotho_Tswana-Setswana  \
# 0   [KGOELETSO, YA, MAIPOLELO, A, ODIT, ·, HABAT, ...
# 1   [Go, ntse, jalo, gore, go, itlhokomolosa, le, ...
# 2   [Go, ntse, jalo, gore, go, botlhokwa, ,, fa, m...
# 3   [Go, ntse, jalo, gore, go, botlhokwa, go, tswe...
# 4   [Go, ntse, jalo, gore, Dit, , haba, Kopano, k...
# 5   [Go, ntse, jalo, gore, Dinaga, tse, e, leng, D...
# 6   [Go, ntse, jalo, gore, go, a, tlhaloganyesega,...
# 7   [Aretikele, 1, Batho, botlhe, ba, tsetswe, ba,...
# 8   [Ba, abetswe, go, akanya, le, maikutlo, ,, mme...
# 9   [Aretikele, 2, Mongwe, le, mongwe, o, na, le, ...
# 10  [Gape, ,, ga, go, pharologanyo, epe, e, e, tla...
# 11  [Aretikele, 3, Mongwe, le, mongwe, o, na, le, ...
# 12  [Aretikele, 4, Ga, go, ope, yo, o, tla, tshwar...
# 13  [Aretikele, 5, Ga, go, ope, yo, o, tla, bogisi...
# 14  [Aretikele, 6, Mongwe, le, mongwe, o, na, le, ...
# 15  [Aretikele, 7, Botlhe, ba, a, lekana, fa, pele...
# 16  [Botlhe, ba, na, le, tetla, e, e, lekanang, ya...
# 17  [Aretikele, 8, Mongwe, le, mongwe, o, na, le, ...
# 18  [Aretikele, 9, Ga, go, ope, yo, o, ka, tshwarw...
#
#                                                 Wolof  \
# 0   [BATAAXAL, GU, MAG, GI, ËMB, SAÑ, -, SAÑI, DOO...
# 1   [Ñu, jàpp, ne, ñakk, xam, ak, soofantal, sañ, ...
# 2   [Temano, egsi, na, ba, mu, nekk, ci, doomi, aa...
# 3   [Ñu, jàpp, ne, am, na, solo, lool, ñu, aar, sa...
# 4   [Ñu, jàpp, ne, am, na, solo, lool, ñu, góor, -...
# 5   [Ñu, jàpp, ne, ci, bataaxal, boobule, mbootaay...
# 6   [Ñu, jàpp, ne, réew, yi, ci, bokk, jël, nañu, ...
# 7   [Ñu, jàpp, ne, ànd, taxawal, sañ, -, sañ, yeek...
# 8   [Ndaje, mu, mag, mi, biral, na, ci, bataaxal, ...
# 9   [Ñu, lawal, sañ, -, sañ, yeek, taawfeex, yi, j...
# 10  [Ñu, nangu, te, di, doxal, fépp, ci, anam, gu,...
# 11  [Matukaay, bu, jëkk, bi, Doomi, aadama, yépp, ...
# 12  [Nekk, na, it, ku, xam, dëgg, te, ànd, na, ak,...
# 13  [Naareelu, matukaay, Ku, ne, mën, naa, wax, ne...
# 14  [Rax, sa, dolli, amul, xeej, ak, seen, ci, pol...
# 15  [Ñatteelu, matukaay, Nit, kune, war, naa, dund...
# 16  [Njaam, ak, njaayum, jaam, nanguwunu, ko, ci, ...
# 17  [Juróomeelu, matukaay, Waruñoo, mbugal, ,, tut...
# 18  [Juróom, benneeli, matukaay, Nit, ku, ne, am, ...
#
#                                                 Xhosa  \
# 0   [INKCAZO, -, JIKELELE, NGEEMFANELO, ZOLUNTU, I...
# 1   [Njengoko, ukungananzi, nokudelelwa, kweemfane...
# 2   [Kwananjalo, kubalulekile, ke, ngoko, ,, ukuba...
# 3   [Njengoko, uluntu, Lwezizwe, Ezimanyeneyo, lut...
# 4   [Njengoko, amalungu, obuRhulumente, kunye, naw...
# 5   [Njengoko, iimvisiswano, zesidima, soluntu, ne...
# 6   [Inqaku, loku, -, 1, Bonke, abantu, bazalwa, b...
# 7   [Bonke, abantu, banesiphiwo, sesazela, nesizat...
# 8   [Inqaku, lesi, -, 2, Wonke, umntu, unamalungel...
# 9   [Ngaphezu, koko, ,, akukho, mahluko, unokwenzi...
# 10  [Inqaku, lesi, -, 3, Wonke, umntu, unelungelo,...
# 11  [Inqaku, lesi, -, 4, Akukho, namnye, oya, kugc...
# 12  [Inqaku, lesi, -, 5, Akukho, namnye, oyakuphat...
# 13  [Inqaku, lesi, -, 6, Wonke, umntu, unelungelo,...
# 14  [Inqaku, lesi, -, 7, Bonke, abantu, bayalingan...
# 15  [Bonke, abantu, banelungelo, lokhuselo, olulin...
# 16  [Inqaku, lesi, -, 8, Wonke, umntu, unelungelo,...
# 17  [Inqaku, le, -, 9, Akukho, namnye, oza, kubanj...
# 18  [Inqaku, le, -, 10, Wonke, umntu, unelungelo, ...
#
# 5   [Gubine, gidii, mabay, matt, , awen, ko, biro...
# 6   [Dab, nikel, bee, , ngantay, nimod, e, sib, ,...
# 7   [Dab, ni, gafgou, nege, lem, ara, doungin, bee...
# 8   [Gubine, gidii, mabay, matt, , awen, ni, ngan...
# 9   [Gubin, e, gidii, mada, taareb, matt, , awen,...
# 10  [Magubin, e, gidii, makueritay, nibay, matt, ...
# 11  [Gubine, gidii, mabay, matta, , wen, ninge, p...
# 12  [Dab, nipos, mini, tay, liben, bee, , nganin,...
# 13  [Gubine, gidii, maba, matt, , aw, ni, yara, p...
# 14  [Gubine, gidii, ni, kani, eg, neg, u, bapaa, e...
# 15  [Dab, ni, m, , ag, ara, nitay, niba, buche, r...
# 16  [Fa, ni, gechig, nag, ngepag, tolngin, kobin, ...
# 17  [Dab, nog, ni, nge, pigichel, bee, kotirok, ,...
# 18  [Gubine, gidii, mabay, matt, , awen, u, lane,...
#
#                                              Zapoteco  \
# 0   [Kuan, mbe, ', s, men, yuy, par, diti, Kuan, n...
# 1   [Ta, mbe, ', s, ,, kuan, mien, ndixi, gak, xa,...
# 2   [Xa, ndob, kuan, mbes, gak, bxen, men, xa, yen...
# 3   [Xa, ndob, mbes, kuan, ngak, ndixi, nlás, ,, x...
# 4   [Xa, ndob, riet, yets, ,, xa, mbes, ndob, kuer...
# 5   [Xa, ndob, yets, naró, kuan, ndob, kuan, mbes,...
# 6   [Xa, ndob, kuan, gak, par, diti, xa, kuanta, r...
# 7   [Ndob, riet, men, mbes, Kuan, mbes, men, yuy, ...
# 8   [Dib, rtik, (, 1, ), Diti, mien, ndied, xa, ye...
# 9   [Chop, rtik, (, 2, ), Diti, mien, ndob, kuan, ...
# 10  [Bay, ,, na, ngui, cho, kuan, men, nkie, par, ...
# 11  [Tson, rtik, (, 3, ), Rieti, mien, ndob, kuan,...
# 12  [Dapa, rtik, (, 4, ), Yent, men, kuan, nkie, o...
# 13  [Gay, rtik, (, 5, ), Yenti, men, nkie, mbikie,...
# 14  [Xopa, rtik, (, 6, ), Diti, mien, ndob, kuan, ...
# 15  [Gatsa, rtik, (, 7, ), Diti, takuan, ba, mbes,...
# 16  [Xona, rtik, (, 8, ), Diti, mien, ndob, par, m...
# 17  [Yey, rtik, (, 9, ), Yenti, kuan, bxen, lu, ',...
# 18  [Diti, mien, kuan, ngak, kap, ndob, tidib, par...
#
#                             Zapoteco-SanLucasQuiavini  \
# 0   [Declarasyoony, x, :, te, :, e, ', n, Deree, '...
# 1   [Te, ', ihby, (, 1, ), Ra, ', ta, ra, bu, :, u...
# 2   [Ra, :, alyne, :, erih, gahll, ri, :, e, :, en...
# 3   [Tyo, ', p, (, 2, ), Ra, ', ta, ra, bu, :, unn...
# 4   [Chiru, ', mahs, ca, :, atihzhli, za, :, arih,...
# 5   [Cho, :, onn, (, 3, ), Ra, ', ta, ', bu, :, un...
# 6   [Tahp, (, 4, ), Nye, :, e, ', c, te, ', ihby, ...
# 7   [Ga, :, a, ', y, (, 5, ), Nye, :, e, ', c, te,...
# 8   [X, :, o, ', p, (, 6, ), Ra, wbyee, ', rnn, na...
# 9   [Ga, :, az, (, 7, ), Ra, le, ', i, na, :, a, p...
# 10  [Ra, ', ta, ', bu, :, unny, na, :, a, pahr, ga...
# 11  [X, :, o, :, on, (, 8, ), Ra, ', ta, ', jusgaa...
# 12  [Ga, :, a, :, a, ', (, 9, ), Nye, :, e, ', c, ...
# 13  [Tsë, :, ë, '(, 10, ), Ra, ', ta, ', bu, :, un...
# 14  [Ra, ', ta, ', bu, :, unny, nih, ra, :, a, ', ...
# 15  [Nye, :, e, ', cy, te, ', ihby, bu, :, unny, q...
# 16  [Tsëbtyo, ', p, (, 12, ), Nye, :, e, ', c, te,...
# 17  [Na, :, a, pahr, guuny, le, ', i, protejeer, b...
# 18  [Ra, ', ta, ', bu, :, unny, ra, :, a, ', p, de...
#
#                                                Zhuang  \
# 0   [SEIQGYAIQ, YINZGENZ, SENHYENZ, VAH, BAIHNAJ, ...
# 1   [DIUZ, DAIHIT, Boux, boux, ma, daengz, lajmbwn...
# 2   [gyoengq, vunz, miz, lijsing, caeuq, liengzsim...
# 3   [DIUZ, DAIHNGEIH, Boux, boux, miz, cwhgwz, yie...
# 4   [Lij, mbouj, ndeij, aenvih, boux, vunz, guekgy...
# 5   [DIUZ, DAIHSAM, Boux, boux, miz, sengmingh, ,,...
# 6   [DIUZ, DAIHSEIQ, Boux, lawz, hix, mbouj, ndeij...
# 7   [DIUZ, DAIHHAJ, Boux, lawz, hix, mbouj, ndeij,...
# 8   [DIUZ, DAIHROEK, Boux, boux, youq, gizlawz, cu...
# 9   [DIUZ, DAIHCAET, Youq, naj, fazliz, vunzvunz, ...
# 10  [vunzvunz, miz, genz, yiengjsou, bingzdaengj, ...
# 11  [DRUZ, DAIHBET, Mbouj, guenj, boux, lawz, ,, d...
# 12  [DIUZ, DAIGOUJ, Boux, lawz, hix, mbouj, deng, ...
# 13  [DIUZ, DAIHCIB, Vunz, vunz, miz, vanzcienz, bi...
# 14  [(, IT, ), gij, boux, deng, hingzsw, cigung, ,...
# 15  [(, NGEIH, ), Mbouj, guenj, bouxvunz, he, guh,...
# 16  [hingzfap, mbouj, ndeij, naek, gvaq, seiz, fam...
# 17  [Mbouj, guenj, boux, lawz, ,, gij, swhswnghhoz...
# 18  [3, ., hingfap, hix, mboujndaej, naek, gvaq, m...
#
#                                                  Zulu
# 0   [UMBHALO, OGCWELE, WOGUNYAZO, LWAMALUNGELO, OL...
# 1   [Isigaba, 2, Wonke, umuntu, kumele, awathole, ...
# 2   [Ngaphezu, kwaloko, ,, akukho, kuhlukaniswa, o...
# 3   [Isigaba, 4, Akekho, oyoba, isigqila, noma, ag...
# 4   [Isigaba, 5, Akekho, oyohlukunyezwa, noma, aph...
# 5   [Isigaba, 6, Wonke, umuntu, unelungelo, lokwem...
# 6   [Isigaba, 7, Sonke, siyalingana, phambi, komth...
# 7   [Sonke, kufanele, sivikelwe, ngokulinganayo, e...
# 8   [Isigaba, 8, Wonke, umuntu, unelungelo, lokuth...
# 9   [Isigaba, 9, Akekho, oyoboshwa, ,, avelelwe, n...
# 10  [Isigaba, 10, Wonke, umuntu, kumele, alalelwe,...
# 11  [Wonke, umuntu, obekwe, icala, elidinga, isije...
# 12  [Akekho, oyotholwa, enecala, ngecala, elidinga...
# 13  [Isigaba, 12, Akekho, okuyogaxekwa, ,, ngokung...
# 14  [Wonke, umuntu, unelungelo, lokuhamba, ngenkul...
# 15  [Wonke, umuntu, unelungelo, lokushiya, izwe, l...
# 16  [Wonke, umuntu, unelungelo, lokucela, ukuhlala...
# 17  [Lelilungelo, alinakusetshenziselwa, ukubaleke...
# 18  [Abesilisa, nabesifazane, asebeneminyaka, efan...
#
# [19 rows x 190 columns]

# %%
languages = pd.Series([lang for lang in corpus.columns])

# %% [markdown]
# Now that we have a dataset (and a suite of tools for adding to the dataset), let's focus on getting the LLM to learn the condition in context and evaluate the LLM's learning.

# %%
lang = 'Swaheli'

# %%
corpus.loc[:, corpus.columns != lang]
# Out:
#                                             Achehnese  \
# 0   [PEUNYATAANUMUM, TEUNTANG, HAK, -, HAK, ASASI,...
# 1   [Tiep, ureung, lahee, dengon, hak, -, hak, dro...
# 2   [Pane, ", komitmen, ", bak, awai, phon, ,, put...
# 3   [Cempala, kuneng, jipoue, ue, baroh, cicem, ce...
# 4   [PEUNYATAAN, UMUM, TEUNTANG, HAK, ASASI, MANUS...
# 5   [P, a, s, a, i, 1, Bandum, manusia, lahee, beb...
# 6   [Ngon, akai, taseumikee, ,, ngon, atee, tameur...
# 7   [P, a, s, a, i, 2, Tiep, ureung, na, hak, saba...
# 8   [Basa, ,, agama, ,, sukee, ngon, bangsa, hana,...
# 9   [P, a, s, a, i, 3, Ureung, droe, -, droe, bak,...
# 10  [P, a, s, a, i, 4, Hana, sidroe, ureung, bak, ...
# 11  [P, a, s, a, i, 5, Tan, sidroe, ureung, patot,...
# 12  [P, a, s, a, i, 6, Tiep, -, tiep, ureung, cit,...
# 13  [P, a, s, a, i, 7, Tiep, ureung, saban, bak, m...
# 14  [Patot, hai, rakan, tanyoe, tapuphom, hanjeut,...
# 15  [P, a, s, a, i, 8, Tiep, ureung, na, hak, teur...
# 16  [P, a, s, a, i, 9, Hana, sidroe, ureung, hai, ...
# 17  [P, a, s, a, i, 10, Bandum, ureung, ,, hai, te...
# 18  [Barangasoe, didakwa, lee, hukom, hanjeut, hai...
# 19  [Hana, sidroe, ureung, jeut, tapeusalah, yoh, ...
# 20  [P, a, s, a, i, 12, Hukom, nasional, dan, inte...
# 21  [Tiep, -, tiep, ureung, na, hak, dijak, hoe, -...
# 22  [Tiep, -, tiep, ureung, nak, hak, droe, pinah,...
# 23  [Bandum, ureung, deungon, niet, droe, na, hak,...
# 24  [Bek, tapeusaban, wahei, nyak, awan, ngon, peu...
# 25  [Tiep, ureung, na, hak, maseng, -, maseng, dro...
# 26  [Hana, barangsoe, ban, mangat, asoe, droe, peu...
# 27  [Meunyoe, ban, bandum, galak, bok, rambot, han...
# 28  [Hak, meukawen, ngon, meuchree, pih, hana, pan...
# 29  [Oreung, nyang, meukawen, ,, hai, puteh, licen...
# 23  [Articulo, 12, Pishtacovin, tzova, ja, jahacom...
# 24  [Jatoqui, yovanquin, ", hiromamun, nan, jonihn...
# 25  [Nan, quiricanan, jau, cuzati, yohiquin, cunuu...
# 26  [Jau, cuzayamaxo, jato, hachipaiiquin, jato, v...
# 27  [Coonrocon, hiromaquin, jau, cuzahax, jaton, n...
# 28  [Tzova, pishtacovin, jato, ", min, nutunoha, j...
# 29  [Jonix, moha, puxcoonix, hainhaivaun, caahiriv...
# 30  [Nan, yora, joxoya, vihannahax, ,, nan, yora, ...
# 31  [Ja, jahaquin, jau, cuzati, yohiquin, jaton, n...
# 32  [Ja, jato, nichinhai, honivaun, jato, chituyov...
# 33  [Jamun, jaton, hitinrivi, quiyoovinin, jaton, ...
# 34  [Vutza, jonivutan, sharaaquin, yohihoxanhquin,...
# 35  [Jaton, hitin, jato, vutzarazi, ja, jahaquin, ...
# 36  [Jamun, jaton, Dios, cuzaquin, sharaaquin, yoh...
# 37  [Articulo, 19, Jamun, jaton, shinanun, jau, sh...
# 38  [Jamun, jau, honanpaiiquin, honanxon, jau, nin...
# 39  [Ja, jahapaquin, cunuuxon, nichinhoxanhquin, r...
# 40  [Jamun, tziztocohoopaiihi, joni, naha, jaquizt...
# 41  [Jamun, quiyoovinin, jaton, nutun, jaha, hapon...
# 42  [Ja, j, atonvi, jau, cuzahoxanhquin, vutzarivi...
# 43  [Quiyoovi, jato, jaton, hapon, jau, vinonvo, j...
# 44  [Cutzahtin, pishta, varixutuu, vinoohainmun, r...
# 45  [Jamun, j, aton, shinanuruz, quiyoovinin, tzov...
#
#                                            Amarakaeri  \
# 0   [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 1   [Kena, ', po, oro, ', huadakda, ka, ', dik, o,...
# 2   [Kena, ', po, aya, ', da, oro, ', taj, dakhuap...
# 3   [Kenpa, ', ti, oro, ', taj, nama, ', da, e, ',...
# 4   [Daka, ', da, e, ', nigpeetada, dakhuea, ', ek...
# 5   [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 6   [Huabokerek, kenda, oknopoehue, ', o, ', nepo,...
# 7   [Kena, ', po, ,, Do, ', huedbayo, kenda, ijnop...
# 8   [Dakhuea, ', huaka, ', eri, huakka, ', aratbut...
# 9   [Dakhuea, ', huaka, ', eritaj, aratbutnayo, ba...
# 10  [Gobierno, huairi, e, ', mana, ', nigmadoya, '...
# 11  [Kenda, aratbut, nogda, nogda, huadakda, ka, '...
# 12  [Huadaribayo, huairi, nog, huadaribayo, huairi...
# 13  [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 14  [Oro, ', nogbayo, nogbayo, gobierno, huairi, o...
# 15  [Aya, ', da, huabokerek, konigti, huadakda, o,...
# 16  [Huabokerekere, ettone, ', ere, konigti, huada...
# 17  [Nogiti, nogiti, nogomeya, e, ', tihuapok, ken...
# 18  [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 19  [Kenda, oro, ', huadari, huairi, oro, ', en, h...
# 20  [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 21  [Oro, ', aya, ', da, nopoenka, ', dik, o, ', e...
# 22  [Aka, ', ya, ', po, kenda, o, ', madoya, ', de...
# 23  [Kena, ', po, AYA, ', DA, NOGDA, NOGDA, HUADAR...
# 24  [Nogda, nogda, huadak, eka, ', aya, ', da, ara...
# 25  [Kenda, aya, ', huairia, o, ', mana, ', po, on...
# 26  [Aya, ', huairi, kenpa, ', ti, aya, ', aratbut...
# 27  [Oro, ', enbayo, aratbut, kenpa, ', ti, nogbay...
# 28  [Aya, ', da, aratbut, katepi, ', eka, ', ta, '...
# 29  [Nog, aratbut, huadak, o, ', nepo, konigti, op...
# 30  [Aya, ', da, huadak, eka, ', nopoe, ', dik, o,...
# 31  [Huabokerek, katepi, ', aratbut, o, ', epo, ,,...
# 32  [Kenpa, ', ti, katepi, ', gobierno, huairi, o,...
# 33  [Aya, ', da, huadak, eka, ', ta, ', on, ', pak...
# 34  [Aya, ', da, me, ', pukhue, ', o, ', nepo, noi...
# 35  [Be, ', api, ', ya, , e, huanaba, ', katetehu...
# 36  [Kenpa, ', ti, huanaba, ', huakupete, bahuayah...
# 37  [Dakhuea, ', da, egka, ', konig, huabokerektaj...
# 38  [Ontaj, a, ', biraya, ', po, dakhuea, ', kahue...
# 39  [Ontaj, diga, ', da, mabitbithue, ', dik, o, '...
# 40  [Gobierno, huairia, aya, ', da, huabokerekeret...
# 41  [Aya, ', tada, konigti, pee, ', dik, o, ', ne,...
# 42  [Huanaba, ', taj, konigti, pee, ', dik, o, ', ...
# 43  [Be, ', api, ', ea, ', te, kena, ', po, tihuap...
# 44  [Nogda, nogda, huadak, eka, ', aya, ', da, hua...
# 45  [Gobierno, huairia, o, ', madoya, ', nok, ,, k...
#
#                                               Arabela  \
# 0   [PUETUNU, PUEYAPUEECUARAJANAA, NIYA, NAAJIOSAA...
# 1   [Pocua, naa, quiri, paa, jaara, rerequeteyaqui...
# 2   [Paa, niishiyani, :, pueya, jaara, jiyaniquiaa...
# 3   [Maninia, pueyari, shiriiquirii, na, niishisha...
# 4   [Pueya, jaara, sesa, niishiyajaa, naa, ,, maja...
# 5   [Paa, cartesano, quiniu, paniyapa, sequenura, ...
# 6   [Paa, niishiyani, :, pueya, cuaara, maninia, j...
# 7   [Paa, niishiyani, :, pueya, cuaara, jiyano, ¿,...
# 8   [Paa, niishiyani, :, puetunu, pajaniyajanaa, p...
# 9   [Paa, mariyata, sequequiaari, :, -, Pa, poonij...
# 10  [Paa, niishiyani, :, puetunu, jiyaniijiajanaar...
# 11  [Paa, niishiyani, :, Noojiaqueya, pueya, niish...
# 12  [Naaratej, :, Puetunu, canaaj, anaa, canaa, re...
# 13  [Nia, numaama, nia, racatare, canaa, sequesano...
# 14  [Jiyaniijianucua, cuaara, sequeera, taa, miish...
# 15  [Cuaara, niishitiojosaaria, puetunu, na, pueya...
# 16  [Pueyano, pa, quishacari, ,, puetunu, pajaniya...
# 17  [Na, camaru, mariyata, maninia, miishiya, taa,...
# 18  [Mariyata, sesa, miijia, maja, saniitioshiya, ...
# 19  [Pueyano, jaara, tamonu, jiyajinia, rucuanejiy...
# 18  [Te, oncameetsateji, iroatsinayeeteri, atiri, ...  ...
# 19  [Te, oncameetsatej, i, incantajeitee, a, gobie...  ...
# 20  [Queario, aquempetavacaajeitaca, Ocameetsati, ...  ...
# 21  [Terica, ontime, antayetiri, ,, te, oncameetsa...  ...
# 22  [Intimerica, cantatsineri, otimi, caari, camee...  ...
# 23  [Ariorica, intime, atiri, cantacoventeeri, :, ...  ...
# 24  [1ro, cantaincha, te, oncameetsateji, incante,...  ...
# 25  [Te, oncameetsateji, incantashijeite, ashaninc...  ...
# 26  [Ancoaquerica, ajate, pashiniqui, quipatsi, ,,...  ...
# 27  [Ariorica, inquisashijeitee, ashanincapee, aro...  ...
# 28  [1ro, cantaincha, ariorica, antaquero, caari, ...  ...
# 29  [Aisati, te, oncameetsateji, incantee, :, ", E...  ...
# 30  [Ariorica, irantearitaque, shirampari, aisati,...  ...
# 31  [Te, oncameetsateji, incanteeteri, :, ", Te, p...  ...
# 32  [Opincatsataca, irosati, :, oshinetaca, oncant...  ...
# 33  [Terica, incoye, shirampari, iraye, ,, aisati,...  ...
# 34  [Ocameetsati, irashitearo, apaniro, ,, aisati,...  ...
# 35  [Ocameetsati, anquenqueshiretero, paitapeerica...  ...
# 36  [Ocameetsati, amajeitero, apaniro, ,, aisati, ...  ...
# 37  [Ocameetsati, anquenqueshiretero, paitapeerica...  ...
# 38  [Terica, ancoye, ,, te, oncameetsateji, incant...  ...
# 39  [Ariorica, ancamantasanoteri, arori, :, terica...  ...
# 40  [Te, oncameetsateji, incanteetee, :, ", Te, pi...  ...
# 41  [Te, oncameetsátej, i, impincatsatashitea, avi...  ...
# 42  [Ocameetsati, asanquenatero, ,, te, oncameetsa...  ...
# 43                                                NaN  ...
# 44                                                NaN  ...
# 45                                                NaN  ...
#
#                          WesternSotho_Tswana-Setswana  \
# 0   [KGOELETSO, YA, MAIPOLELO, A, ODIT, ·, HABAT, ...
# 1   [Go, ntse, jalo, gore, go, itlhokomolosa, le, ...
# 2   [Go, ntse, jalo, gore, go, botlhokwa, ,, fa, m...
# 3   [Go, ntse, jalo, gore, go, botlhokwa, go, tswe...
# 4   [Go, ntse, jalo, gore, Dit, , haba, Kopano, k...
# 5   [Go, ntse, jalo, gore, Dinaga, tse, e, leng, D...
# 6   [Go, ntse, jalo, gore, go, a, tlhaloganyesega,...
# 7   [Aretikele, 1, Batho, botlhe, ba, tsetswe, ba,...
# 8   [Ba, abetswe, go, akanya, le, maikutlo, ,, mme...
# 9   [Aretikele, 2, Mongwe, le, mongwe, o, na, le, ...
# 10  [Gape, ,, ga, go, pharologanyo, epe, e, e, tla...
# 11  [Aretikele, 3, Mongwe, le, mongwe, o, na, le, ...
# 12  [Aretikele, 4, Ga, go, ope, yo, o, tla, tshwar...
# 13  [Aretikele, 5, Ga, go, ope, yo, o, tla, bogisi...
# 14  [Aretikele, 6, Mongwe, le, mongwe, o, na, le, ...
# 15  [Aretikele, 7, Botlhe, ba, a, lekana, fa, pele...
# 16  [Botlhe, ba, na, le, tetla, e, e, lekanang, ya...
# 8   [Inqaku, lesi, -, 2, Wonke, umntu, unamalungel...
# 9   [Ngaphezu, koko, ,, akukho, mahluko, unokwenzi...
# 10  [Inqaku, lesi, -, 3, Wonke, umntu, unelungelo,...
# 11  [Inqaku, lesi, -, 4, Akukho, namnye, oya, kugc...
# 12  [Inqaku, lesi, -, 5, Akukho, namnye, oyakuphat...
# 13  [Inqaku, lesi, -, 6, Wonke, umntu, unelungelo,...
# 14  [Inqaku, lesi, -, 7, Bonke, abantu, bayalingan...
# 15  [Bonke, abantu, banelungelo, lokhuselo, olulin...
# 16  [Inqaku, lesi, -, 8, Wonke, umntu, unelungelo,...
# 17  [Inqaku, le, -, 9, Akukho, namnye, oza, kubanj...
# 18  [Inqaku, le, -, 10, Wonke, umntu, unelungelo, ...
# 19  [Wonke, umntu, omangalelwe, kuba, enetyala, ,,...
# 20  [Akukho, namnye, oya, kufunyanwa, enesohlwayo,...
# 21  [Inqaku, le, -, 12, Akukho, namnye, oya, kupha...
# 22  [Wonke, umntu, unelungelo, lokushiya, nokuba, ...
# 23  [Wonke, umntu, unelungelo, lokucela, aze, axha...
# 24  [Eli, lungelo, alinakukhuselwa, wakumangalelwa...
# 25  [Akukho, namnye, oya, kuhluthwa, ubuhlanga, ba...
# 26  [Amadoda, namakhosikazi, aselekhulile, ,, ngap...
# 27  [Kuya, kutshatwa, ngokukhululekileyo, nangokup...
# 28  [Usapho, lusisisekelo, esibalulekileyo, sendal...
# 29  [Wonke, umntu, unelungelo, lokuba, nezinto, ez...
# 30  [Inqaku, le, -, 18, Wonke, umntu, unelungelo, ...
# 31  [Inqaku, le, -, 19, Wonke, umntu, unelungelo, ...
# 32  [Wonke, umntu, unelungelo, lokuthabatha, inxax...
# 33  [Intando, yoluntu, iya, kuba, sisisekelo, semp...
# 34  [Inqaku, la, -, 22, Wonke, umntu, njengelungu,...
# 35  [Wonke, umntu, unelungelo, lokusebenza, ,, uku...
# 36  [Wonke, umntu, ngaphandle, komkhethe, ,, unelu...
# 37  [Wonke, umntu, osebenzayo, unelungelo, lobulun...
# 38  [Wonke, umntu, unelungelo, lokubumba, okanye, ...
# 39  [Inqaku, la, -, 24, Wonke, umntu, unelungelo, ...
# 40  [Wonke, umntu, unelungelo, lentlalo, esemganga...
# 41  [Imfundo, ngezobugcisa, kunye, nokufundela, um...
# 42  [Imfundo, iza, kujoliswa, ngqo, kwinkqubela, p...
# 43  [Iza, kuxhasa, imvisiswano, ,, ukunyamezelana,...
# 44  [Abazali, banelungelo, elibalulekileyo, lokukh...
# 45  [Wonke, umntu, unelungelo, lokuthabatha, inxax...
#
#                                                 Yagua  \
# 0   [TUCHODA, TITAJU, NIJYANVAJYU, VURYATIDYE, VIC...
# 1   [Riñuyadivasirya, j, irya, niquejada, ,, ruted...
# 2   [TUCHODA, TITAJU, NIJYANVAJYU, VURYATIDYE, VIC...
# 3   [Ramunjtiy, vutyuchura, jiryatiy, nijyanvay, v...
# 4   [Riñiquery, ntyuvachuruy, variy, jivyatadamusi...
# 44  [Xa, diti, mien, bix, kuan, kino, xutl, o, cho...
# 45  [Diti, men, kino, kuan, nlas, par, nta, ', ted...
#
#                             Zapoteco-SanLucasQuiavini  \
# 0   [Declarasyoony, x, :, te, :, e, ', n, Deree, '...
# 1   [Te, ', ihby, (, 1, ), Ra, ', ta, ra, bu, :, u...
# 2   [Ra, :, alyne, :, erih, gahll, ri, :, e, :, en...
# 3   [Tyo, ', p, (, 2, ), Ra, ', ta, ra, bu, :, unn...
# 4   [Chiru, ', mahs, ca, :, atihzhli, za, :, arih,...
# 5   [Cho, :, onn, (, 3, ), Ra, ', ta, ', bu, :, un...
# 6   [Tahp, (, 4, ), Nye, :, e, ', c, te, ', ihby, ...
# 7   [Ga, :, a, ', y, (, 5, ), Nye, :, e, ', c, te,...
# 8   [X, :, o, ', p, (, 6, ), Ra, wbyee, ', rnn, na...
# 9   [Ga, :, az, (, 7, ), Ra, le, ', i, na, :, a, p...
# 10  [Ra, ', ta, ', bu, :, unny, na, :, a, pahr, ga...
# 11  [X, :, o, :, on, (, 8, ), Ra, ', ta, ', jusgaa...
# 12  [Ga, :, a, :, a, ', (, 9, ), Nye, :, e, ', c, ...
# 13  [Tsë, :, ë, '(, 10, ), Ra, ', ta, ', bu, :, un...
# 14  [Ra, ', ta, ', bu, :, unny, nih, ra, :, a, ', ...
# 15  [Nye, :, e, ', cy, te, ', ihby, bu, :, unny, q...
# 16  [Tsëbtyo, ', p, (, 12, ), Nye, :, e, ', c, te,...
# 17  [Na, :, a, pahr, guuny, le, ', i, protejeer, b...
# 18  [Ra, ', ta, ', bu, :, unny, ra, :, a, ', p, de...
# 19  [Ra, ', ta, ', bu, :, unny, ra, :, a, ', p, de...
# 20  [Chiru, ', ra, ', ta, ', bu, :, unny, ra, :, a...
# 21  [Ra, ', ta, ', bu, :, unny, ra, :, a, ', p, de...
# 22  [Bu, :, unny, quei, ', ty, ra, :, a, ', pdi, '...
# 23           [Tse, :, e, :, i, ', ny, (, 15, ), 1, .]
# 24  [Ra, ', ta, ', bu, :, unny, ra, :, alyne, :, e...
# 25  [Nye, :, e, ', cy, te, ', ihby, bu, :, unny, q...
# 26  [Tse, :, e, :, i, ', ny, Ahbteeby, (, 16, ), 1...
# 27  [Zi, ', cy, mnna, :, a, :, a, ', zi, ', cy, ng...
# 28  [Te, ', blohihzy, deree, ', ch, ra, :, a, ', p...
# 29  [Nye, :, e, ', cy, te, ', ihby, bu, :, unny, q...
# 30  [Importa, ', anndaa, :, a, ', n, na, :, a, fam...
# 31  [Tse, :, e, :, i, ', ny, Ahbtyo, ', p, (, 17, ...
# 32  [Ra, ', ta, ', bu, :, unny, ra, :, a, ', p, de...
# 33  [Nye, :, e, ', c, te, ', ihby, bu, :, unny, qu...
# 34  [Tse, :, e, :, i, ', ny, Ahbcho, :, onn, (, 18...
# 35  [Ra, ', ta, ', bu, :, unny, ra, :, a, ', p, li...
# 36  [Tse, :, e, :, i, ', ny, Ahbta, ', p, (, 19, )...
# 37  [Wbyee, ', rnn, quei, ', ty, na, :, adi, ', pa...
# 31  [(, IT, ), Boux, boux, miz, hozbingz, cizvei, ...
# 32  [(, NGEIH, ), Boux, lawz, hix, mbouj, deng, gi...
# 33  [(, IT, ), Boux, boux, miz, genzli, cizcez, ro...
# 34  [(, NGEIH, ), Boux, boux, miz, bingzdaengj, ca...
# 35  [(, SAM, ), yinzminz, yici, dwg, cingqfuj, gen...
# 36  [DIUZ, DAIHNGEIHCIBNGEIH, Boux, vunz, youq, la...
# 37  [yiengjsou, sizyen, gij, goyinz, cinhyenz, cae...
# 38  [(, IT, ), Boux, boux, miz, genz, gunghcoz, ,,...
# 39  [(, NGEI, ), Boux, boux, miz, genz, dungzgungh...
# 40  [(, SAM, ), Boux, vunz, gunghcoz, ,, miz, genz...
# 41  [(, SEIQ, ), Boux, boux, miz, vihliux, veizhu,...
# 42  [DFUZ, DAIHNGEIHCIBSEIQ, Boux, boux, miz, genz...
# 43  [(, IT, ), Boux, boux, miz, genz, yiengjsou, v...
# 44  [(, NGEIH, ), Meh, lwg, miz, genz, yiengjsou, ...
# 45  [lwgnyez, mboujlwn, lwgseng, lwgndai, ,, wngda...
#
#                                                  Zulu
# 0   [UMBHALO, OGCWELE, WOGUNYAZO, LWAMALUNGELO, OL...
# 1   [Isigaba, 2, Wonke, umuntu, kumele, awathole, ...
# 2   [Ngaphezu, kwaloko, ,, akukho, kuhlukaniswa, o...
# 3   [Isigaba, 4, Akekho, oyoba, isigqila, noma, ag...
# 4   [Isigaba, 5, Akekho, oyohlukunyezwa, noma, aph...
# 5   [Isigaba, 6, Wonke, umuntu, unelungelo, lokwem...
# 6   [Isigaba, 7, Sonke, siyalingana, phambi, komth...
# 7   [Sonke, kufanele, sivikelwe, ngokulinganayo, e...
# 8   [Isigaba, 8, Wonke, umuntu, unelungelo, lokuth...
# 9   [Isigaba, 9, Akekho, oyoboshwa, ,, avelelwe, n...
# 10  [Isigaba, 10, Wonke, umuntu, kumele, alalelwe,...
# 11  [Wonke, umuntu, obekwe, icala, elidinga, isije...
# 12  [Akekho, oyotholwa, enecala, ngecala, elidinga...
# 13  [Isigaba, 12, Akekho, okuyogaxekwa, ,, ngokung...
# 14  [Wonke, umuntu, unelungelo, lokuhamba, ngenkul...
# 15  [Wonke, umuntu, unelungelo, lokushiya, izwe, l...
# 16  [Wonke, umuntu, unelungelo, lokucela, ukuhlala...
# 17  [Lelilungelo, alinakusetshenziselwa, ukubaleke...
# 18  [Abesilisa, nabesifazane, asebeneminyaka, efan...
# 19  [Kufanele, babenamalungelo, alinganayo, ngokom...
# 20  [Isigaba, 18, Wonke, umuntu, unelungelo, lokuc...
# 21  [Isigaba, 19, Wonke, umuntu, unelungelo, lokuv...
# 22  [Wonke, umuntu, unelungelo, lokubamba, iqhaza,...
# 23  [Wonke, umuntu, unelungelo, elilinganayo, loku...
# 24  [Lentando, iyovezwa, okhethweni, lwempela, nge...
# 25  [Isigaba, 22, Wonke, umuntu, ,, njengelunga, l...
# 26  [Wonke, umuntu, unelungelo, lokusebenza, ,, no...
# 27  [Wonke, umuntu, ,, ngaphandle, kokubandlululwa...
# 28  [Wonke, umuntu, osebenzayo, unelungelo, lomhol...
# 29  [Wonke, umuntu, unelungelo, lokubumba, noma, l...
# 30  [Isigaba, 24, Wonke, umuntu, unelungelo, lokup...
# 31  [Wonke, umuntu, unelungelo, lezinga, lempilo, ...
# 32  [Bonke, abantwana, noma, bezalwe, ngaphandle, ...
# 33  [Imfundo, yobuchwepheshe, neyenzululwazi, iyok...
# 34  [Imfundo, iyoqonda, ekuthuthukiseni, ubuntu, n...
# 35  [Iyothuthukisa, ukuzwana, ,, ukubekezelelana, ...
# 36  [Wonke, umuntu, unelungelo, elikhululekile, lo...
# 37  [Wonke, umuntu, unelungelo, lokuvikeleka, kwez...
# 38  [Isigaba, 28, Wonke, umuntu, emphakathini, nas...
# 39  [Wonke, umuntu, uneqhaza, emphakathini, okuwuk...
# 40  [Ekusebenziseni, amalungelo, nenkululeko, yakh...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
#
# [46 rows x 189 columns]

# %%
def build_training_sentences_true(corpus, lang, train_k = 3, seed = None):
    training_sentences_true = corpus[lang].sample(train_k, random_state = seed)
    return training_sentences_true

def build_training_sentences_false(corpus, lang, train_k = 3, seed = None):
    sample_space_false = corpus.loc[:, corpus.columns != lang]
    training_sentences_false = pd.Series([sample_space_false.sample(axis = 0, random_state = seed).sample(axis = 1, random_state = seed).iloc[0, 0] for _ in range(train_k)])
    return training_sentences_false

# %%
def build_test_sentences_true(corpus, lang, training_sentences_true, test_k = 10, seed = None):
    sample_space_true = corpus[~corpus.index.isin(training_sentences_true.index)][lang]
    test_sentences_true = sample_space_true.sample(test_k, random_state = seed)
    return test_sentences_true
    
def build_test_sentences_false(corpus, lang, training_sentences_false, test_k = 10, seed = None):
    sample_space_false = corpus.loc[:, corpus.columns != lang]
    sample_space_false = sample_space_false[~sample_space_false.index.isin(training_sentences_false.index)]
    test_sentences_false = pd.Series([sample_space_false.sample(axis = 0, random_state = seed).sample(axis = 1, random_state = seed).iloc[0, 0] for _ in range(test_k)])
    return test_sentences_false

# %%
def build_train_test_data(corpus, lang, train_k = 3, test_k = 10, seed = None):
    
    train_true = build_training_sentences_true(corpus, lang, train_k, seed)
    train_false = build_training_sentences_false(corpus, lang, train_k, seed)

    test_true = build_test_sentences_true(corpus, lang, train_true, test_k, seed)
    test_false = build_test_sentences_false(corpus, lang, train_false, test_k, seed)

    return train_true, train_false, test_true, test_false

# %%
example_language = 'English'

# %%
train_true = build_training_sentences_true(corpus, example_language)
train_false = build_training_sentences_false(corpus, example_language)
test_true = build_test_sentences_true(corpus, example_language, train_true)
test_false = build_test_sentences_false(corpus, example_language, train_false)

# %%
test_true
# Out:
# 3     [Whereas, it, is, essential, to, promote, the,...
# 29    [This, right, may, not, be, invoked, in, the, ...
# 11    [Furthermore, ,, no, distinction, shall, be, m...
# 41    [Everyone, has, the, right, to, equal, access,...
# 8     [Article, 1, All, human, beings, are, born, fr...
# 9     [They, are, endowed, with, reason, and, consci...
# 37    [Article, 19, Everyone, has, the, right, to, f...
# 19    [Article, 9, No, one, shall, be, subjected, to...
# 35    [Article, 17, Everyone, has, the, right, to, o...
# 23    [Nor, shall, a, heavier, penalty, be, imposed,...
# Name: English, dtype: object

# %%
def prompt(train_sentences_true, train_sentences_false, test_s):
    p = "Each of the following sentences is labeled 'Yes' if it follows a secret rule and labeled 'No' otherwise:\n\n"
    
    for s in train_sentences_true:
        p += "\"" + detokenize(s)[:50] + "\": Yes;\n"

    for s in train_sentences_false:
        p += "\"" + detokenize(s)[:50] + "\": No;\n"

#    p += "\nFirst, state the condition as briefly as possible. Then, state 'Label: True' if the following sentence satisfies the condition and 'Label: False' otherwise.\n\n"
#    p += "\nReply 'Condition: <describe the secret condition briefly>' and on a new line write 'Condition satisfied: <True or False>' where the condition is satisfied if the next sentence satisfies the condition:\n\n"
    p += "\nYour job is to learn the secret rule, thinking carefully about the previous examples. Does the sentence:\n\n"
    try: p += "\"" + detokenize(test_s)[:50] + "\""
    except: 
        print(test_s)
        return TypeError
    p += "\n\nfollow the rule? Give a 'Yes' or 'No' answer, with no explanation."
    return p

# %%
def get_response(p):
    response = client.completions.create(
                model = "gpt-3.5-turbo-instruct",
                prompt = p
                )
    return response.choices[0].text

# %%
example_language = 'Norwegian'

# %%
train_true = build_training_sentences_true(corpus, example_language)
train_false = build_training_sentences_false(corpus, example_language)
test_true = build_test_sentences_true(corpus, example_language, train_true)
test_false = build_test_sentences_false(corpus, example_language, train_false)

# %%
test_true.iloc[0]
# Out:
# ['Undervisningen',
#  'skal',
#  'være',
#  'gratis',
#  ',',
#  'i',
#  'det',
#  'minste',
#  'på',
#  'de',
#  'elementære',
#  'og',
#  'grunnleggende',
#  'trinn',
#  '.']

# %%
print(prompt(train_true, train_false, test_true.iloc[0]))
# Out:
# Each of the following sentences is labeled 'Yes' if it follows a secret rule and labeled 'No' otherwise:
#
# "Enhver har rett til en levestandard som er tilstre": Yes;
# "Ingen må utsettes for vilkårlig arrest, fengsling ": Yes;
# "Enhver som er anklaget for en straffbar handling h": Yes;
# "Pasal 19 Setiap orang berhak atas kebebasan mempun": No;
# "Na tamata kece e nodra na dodonu kei na galala e t": No;
# "Ingen må vilkårligt berøves sin nationalitet eller": No;
#
# Your job is to learn the secret rule, thinking carefully about the previous examples. Does the sentence:
#
# "Undervisningen skal være gratis, i det minste på d"
#
# follow the rule? Give a 'Yes' or 'No' answer, with no explanation.

# %%
train_true, train_false, test_true, test_false = build_train_test_data(corpus, 'English')

# %%
p = prompt(train_true, train_false,test_true.iloc[0] )

# %%
p = prompt(train_true, train_false,test_true.iloc[0] )

# %%
print(p)
# Out:
# Each of the following sentences is labeled 'Yes' if it follows a secret rule and labeled 'No' otherwise:
#
# "Article 3 Everyone has the right to life, liberty ": Yes;
# "Article 17 Everyone has the right to own property ": Yes;
# "Article 18 Everyone has the right to freedom of th": Yes;
# "Karos ahniki de paiki epwelpen pahn kosonned ohng ": No;
# "Paa niishiyani: Noojiaqueya pueya niishiyaquishaca": No;
# "Enhver har rett til å danne og gå inn i fagforenin": No;
#
# Your job is to learn the secret rule, thinking carefully about the previous examples. Does the sentence:
#
# "Proclaims this Universal Declaration of Human Righ"
#
# follow the rule? Give a 'Yes' or 'No' answer, with no explanation.

# %%
response = get_response(p)

# %%
print(response)
# Out:
# Yes

# %%
def evaluate_icl(corpus, lang, train_true = None, train_false = None, k_train = 3, k_test = 10, seed = None, verbose = True):

    test_true = build_test_sentences_true(corpus, lang, train_true, test_k = k_test, seed = seed)
    test_false = build_test_sentences_false(corpus, lang, train_false, test_k = k_test, seed = seed)
    
    num_successes = 0
    #test on True
    for s in test_true:
        if verbose:
            print(s)
        p = prompt(train_true, train_false, s)
        response = get_response(p)
        if 'Yes' in response:
            num_successes += 1
        else:
            if verbose:
                print('On test sentence: '+ detokenize(s) + ' -- the LLM incorrectly evaluates as No')

    #test on False
    for s in test_false:
        p = prompt(train_true, train_false, s)
        response = get_response(p)
        if 'No' in response:
            num_successes += 1
        else:
            if verbose:
                print('On test sentence: '+ detokenize(s) + ' -- the LLM incorrectly evaluates as Yes')

    accuracy = num_successes/(len(test_true) + len(test_false))

#    print('The LLM\'s accuracy is {}'.format(accuracy))
    return accuracy

# %%
train_true, train_false, test_true, test_false = build_train_test_data(corpus, 'English')

# %%
train_false
# Out:
# 0    [Atikol, 24, Evriwan, i, gat, raet, blong, spe...
# 1    [Tenon, deù, dret, parer, pà, se, maridâ, ,, v...
# 2    [Ang, mga, kalalakihan, kag, kababaihan, nga, ...
# dtype: object

# %%
for s in test_true:
    print(detokenize(s))
# Out:
# Enhver har rett til lovens beskyttelse mot slik innblanding eller slike angrep.
# Enhver har rett til liv, frihet og personlig sikkerhet.
# Enhver har rett til i andre land å søke og ta imot asyl mot forfølgelse.
# Alle barn skal ha samme sosiale beskyttelse enten de er født i eller utenfor ekteskap.
# Denne rett kan ikke påberopes ved rettsforfølgelse som har reelt grunnlag i upolitiske forbrytelser eller handlinger som strider mot De Forente Nasjoners formål og prinsipper.
# Ingen må utsettes for tortur eller grusom, umenneskelig eller nedverdigende behandling eller straff.
# Denne rett omfatter frihet til å skifte religion eller tro, og frihet til enten alene eller sammen med andre, og offentlig eller privat, å gi uttrykk for sin religion eller tro gjennom undervisning, utøvelse, tilbedelse og ritualer.
# Enhver har rett til fritt å delta i fredelige møter og organisasjoner.
# Mødre og barn har rett til spesiell omsorg og hjelp.
# Denne vilje skal komme til uttrykk gjennom periodiske og reelle valg med allmenn og lik stemmerett og med hemmelig avstemning eller likeverdig fri stemmemåte.

# %%
evaluate_icl(corpus, 'English', train_true = train_true, train_false = train_false)
# Out:
# On test sentence: The General Assembly, -- the LLM incorrectly evaluates as No
# On test sentence: Now, therefore, -- the LLM incorrectly evaluates as No
# On test sentence: 2. -- the LLM incorrectly evaluates as Yes
# On test sentence: DIUZ DAIHCIBBET Boux boux miz swhsiengj, liengzsim caeuq cunghgyau dih genzli; gij genzli neix baugva de cwyouz gaijbienq cunghgyau roxnaeuz sinqnyangj, danhduz roxnaeuz cizdij, gunghgaih roxnaeuz mimiz yungh gyauyi, sizcenj, lijbai caeuq gailiz biujsi cunghgyau roxnaeuz sinqnyangj de. -- the LLM incorrectly evaluates as Yes
# On test sentence: 3. -- the LLM incorrectly evaluates as Yes
# On test sentence: Ebenso darf keine schwerere Strafe als die zum Zeitpunkt der Begehung der strafbaren Handlung angedrohte Strafe verhängt werden. -- the LLM incorrectly evaluates as Yes
# On test sentence: Mongwe le mongwe o na le tshwanelo ya kgololosego ya motsamao le bonno me melelwaneng yo naga nngwe le nngwe. -- the LLM incorrectly evaluates as Yes
# On test sentence: did oub qaox Leb leb sat mex ad leb xand yanl nend jid pud nangd yad yad nangd njanl lib gaot zib youl, jex guant nis ghob nhangb zongx cul, ghob deud nis ghob nhangb sex daob, nis ghob mpad ghob nit, pud ghob nhangb nangd dut, senb ghob nhangb ghunb, mex ghob nhangb nangd zhenb zib gaot guand dianx. -- the LLM incorrectly evaluates as Yes
# 0.6

# %%
test_set = languages.sample(30)

# %%
test_set
# Out:
# 157                              Swaheli
# 181                                Wolof
# 55                  HaitianCreole_Kreyol
# 104                       Mayan_Yucateco
# 172                              Umbundu
# 164                             TokPisin
# 149                              Siswati
# 93                                Luvale
# 166                         Tongan_Tonga
# 171                        Uighur_Uyghur
# 120                     Nyanja_Chinyanja
# 74                               Italian
# 41                               English
# 52                        German_Deutsch
# 5                         Albanian_Shqip
# 35                         Chuuk_Trukese
# 28                        Catalan_Catala
# 161                                Tetum
# 125                          Otomi_Nahnu
# 96                               Makonde
# 58                         Hausa_Haoussa
# 109                              Mixteco
# 158                    Swahili_Kiswahili
# 53                 Greenlandic_Inuktikut
# 59                            Hiligaynon
# 67                    Icelandic_Yslenska
# 111                              Ndebele
# 108                      Miskito_Miskito
# 60     Hmong_Miao-Sichuan-Guizhou-Yunnan
# 129                                Pipil
# dtype: object

# %%
train_true
# Out:
# 4     [Kwa, kuwa, watu, wa, Umoja, wa, Mataifa, wame...
# 37    [Kila, mtu, ana, haki, ya, kuwa, na, mali, yak...
# 10    [Wote, wamejaliwa, akili, na, dhamiri, ,, hivy...
# 25    [Wala, asipewe, adhabu, kali, zaidi, kuliko, i...
# 44    [Kifungu, cha, 22, Kila, mtu, ,, kama, raia, ,...
# 29    [Kila, mmoja, ana, haki, ya, kuhama, kutoka, n...
# 33    [Watu, wazima, ,, wanaume, kwa, wanawake, wana...
# 19    [Wote, wana, haki, sawa, ya, kulindwa, kutokan...
# 35    [Ndoa, inaweza, kufungwa, tu, kwa, hiari, na, ...
# 39    [Kila, mmoja, ana, haki, ya, uhuru, wa, kutoa,...
# 15    [Mtu, ye, yote, asifanywe, mtumwa, au, mtwana,...
# 1     [Kwa, kuwa, kutojali, na, kudharau, haki, za, ...
# 0     [UMOJA, WA, MATAIFA, OFISI, YA, IDARA, YA, HAB...
# 16    [Mtu, ye, yote, asiteswe, ,, asiadhibiwe, ,, a...
# 18    [Mbele, ya, sheria, watu, wote, ni, sawa, na, ...
# 12    [Yaani, bila, kubaguana, kwa, rangi, ,, taifa,...
# 26    [Kila, mtu, asiingiliwe, bila, sheria, katika,...
# 28    [Kila, mtu, ana, haki, ya, kwenda, mahali, ana...
# 34    [Wana, haki, sawa, za, ndoa, wakati, wa, maish...
# 9     [Watu, wote, wamezaliwa, huru, ,, hadhi, na, h...
# Name: Swaheli, dtype: object

# %%
train_false
# Out:
# 0     [Nog, aratbut, huadak, o, ', nepo, konigti, op...
# 1     [Ndime, 19, Aliyense, ali, ndi, ufulu, kuganiz...
# 2     [Pasal, 20, Setiap, orang, mempunyai, hak, ata...
# 3     [Tódolos, nenos, e, nenas, ,, nacidos, de, mat...
# 4     [Nyumwe, mahasa, kuhisa, nyi, mulonga, ximbu, ...
# 5     [DIUZ, DAIHCIBBET, Boux, boux, miz, swhsiengj,...
# 6                                                   NaN
# 7     [An, lambang, saro, igwa, nin, derecho, na, ma...
# 8     [Dsa, -, ni, '-, nía, h, ', ie, ',, na, -, jua...
# 9     [Mei, wor, an, emon, rait, won, pusin, an, eki...
# 10    [Msit, wen, wejkul, , aqmit, koqwajo, , taqa...
# 11    [Qa, te, juuntl, tnamqe, ,, qa, te, juuntl, ok...
# 12    [Lufunjisho, lwafwainwa, kwikala, lwakuleta, b...
# 13    [Aramas, karos, kak, de, ahniki, manaman, en, ...
# 14    [Unen, emi, ono, enye, odudu, ndiyene, ekikere...
# 15    [Imfundo, ephezulu, yezandla, (, technical, ),...
# 16                                                  NaN
# 17    [Teni, ongomeite, cara, pairiraca, quero, inin...
# 18    [Artikulo, 19, .-, Ay, me, rerecho, ya, slok, ...
# 19    [Tá, ag, gach, uile, dhuine, an, ceart, chun, ...
# dtype: object

# %%
s = ['Buli', 'munhu', 'alinawiyabi', 'bo', 'gusama', ',', 'gwinga', 'na', 'guja', 'nsi', 'yoseyose', 'nulu', 'nsi', 'yakwe', '.']

# %%
import numpy as np

# %%
resp = get_response(p)

# %%
train_false
# Out:
# 0                                                   NaN
# 1     [Ie, aina, illena, ,, nie, eimie, riñona, oiac...
# 2     [Dit, 19, tiaof, Laix, laix, maix, quaif, lit,...
# 3     [La, famiglia, è, il, nucleo, naturale, e, fon...
# 4     [Parentes, in, primis, jus, habent, eligere, g...
# 5     [Muchi, tehemet, tiwelit, nemi, tik, ne, gal, ...
# 6     [Mundu, akasalepelekasikwa, kuwa, jwamchilambo...
# 7     [Si, vite, qu, ', ènn, ', ont, l, ', adje, ,, ...
# 8     [Sigud, nga, adda, iti, pamilya, ken, isu, ', ...
# 9     [Nisha, nisha, piyapi, nipirinhuë, ', napopian...
# 10    [L, ', educació, serà, gratuïta, ,, si, més, n...
# 11    [Jeder, ,, ohne, Unterschied, ,, hat, das, Rec...
# 12                                                  NaN
# 13    [2, ), heqiqeten, gheyriy, siyasiy, jinayet, y...
# 14    [Buli, munhu, adakililwe, gupandika, inongho, ...
# 15    [Anakubala, pamodzi, ndi, ana, ayenera, kupats...
# 16    [Eigi, má, eftir, geðþótta, raska, heimilisfri...
# 17    [Dis, fala, loa, hemi, mek, sua, dat, fo, luk,...
# 18    [Na, lo, mas, stap, long, banisim, dispela, ka...
# 19    [Ang, bawat, tao, ', y, may, karapatang, mag, ...
# dtype: object

# %%
results = {}
for lang in test_set:
    train_true = build_test_sentences_true(corpus, lang, train_true, test_k = 5, seed = None)
    train_false = build_test_sentences_false(corpus, lang, train_false, test_k = 5, seed = None)
    accuracy = evaluate_icl(corpus, lang, train_true, train_false, k_test = 5, verbose = False)
    print('The LLM achieves accuracy {} when learning the rule \"The sentence is in the language {}\".'.format(accuracy, lang))
    results[lang] = accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 4
#       2 for lang in test_set:
#       3     train_true = build_test_sentences_true(corpus, lang, train_true, test_k = 5, seed = None)
# ----> 4     train_false = build_test_sentences_false(corpus, lang, train_false, test_k = 5, seed = None)
#       5     accuracy = evaluate_icl(corpus, lang, train_true, train_false, k_test = 5, verbose = False)
#       6     print('The LLM achieves accuracy {} when learning the rule \"The sentence is in the language {}\".'.format(accuracy, lang))
#
# Cell In[7], line 9, in build_test_sentences_false(corpus, lang, training_sentences_false, test_k, seed)
#       7 sample_space_false = corpus.loc[:, corpus.columns != lang]
#       8 sample_space_false = sample_space_false[~sample_space_false.index.isin(training_sentences_false.index)]
# ----> 9 test_sentences_false = pd.Series([sample_space_false.sample(axis = 0, random_state = seed).sample(axis = 1, random_state = seed).iloc[0, 0] for _ in range(test_k)])
#      10 return test_sentences_false
#
# File ~/miniconda3/envs/openai/lib/python3.12/site-packages/pandas/core/generic.py:6029, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6026 if weights is not None:
#    6027     weights = sample.preprocess_weights(self, weights, axis)
# -> 6029 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6030 result = self.take(sampled_indices, axis=axis)
#    6032 if ignore_index:
#
# File ~/miniconda3/envs/openai/lib/python3.12/site-packages/pandas/core/sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy/random/mtrand.pyx:944, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
accuracy_table = pd.DataFrame.from_dict(results, orient = 'index', columns = ['Accuracy'])

# %%
accuracy_table.sort_values('Accuracy', ascending = False, inplace=True)

# %%
accuracy_table
# Out:
#                                    Accuracy
# Norwegian                             0.800
# NigerianPidginEnglish                 0.775
# Vlach                                 0.750
# Campa_Pajonalino                      0.725
# Cakchiquel                            0.675
# Tojol-abal                            0.650
# Quechua                               0.625
# Tzotzil                               0.625
# Hmong_Miao-Sichuan-Guizhou-Yunnan     0.625
# IrishGaelic_Gaeilge                   0.625
# Arabela                               0.600
# Tenek_Huasteco                        0.600
# HaitianCreole_Kreyol                  0.600
# German_Deutsch                        0.600
# Iloko_Ilocano                         0.575
# Waray                                 0.575
# Norwegian_Norsk-Nynorsk               0.575
# Zulu                                  0.575
# Mayan_Yucateco                        0.575
# Runyankore-rukiga_Nkore-kiga          0.575
# Samoan                                0.575
# Oshiwambo_Ndonga                      0.550
# Basque_Euskara                        0.550
# Ngangela_Nyemba                       0.550
# Urarina                               0.550
# Tongan_Tonga                          0.550
# Rarotongan_MaoriCookIslands           0.550
# Chickasaw                             0.525
# Cashibo-Cacataibo                     0.525
# Malagasy                              0.525
